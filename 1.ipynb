# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Hey so this is the markdown tab.

# %%
x = np.random.normal(0,1,1000)
y = np.random.normal(1,1,1000)

z = x + y

plt.hist(z, bins=10)
# Out:
# (array([  8.,  32.,  94., 166., 223., 236., 138.,  72.,  26.,   5.]),
#  array([-3.23569573, -2.37935036, -1.523005  , -0.66665963,  0.18968574,
#          1.04603111,  1.90237647,  2.75872184,  3.61506721,  4.47141258,
#          5.32775794]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Alright, so things seems working.

# %%
plt.hist(x)
# Out:
# (array([  6.,  21.,  94., 167., 274., 241., 122.,  61.,  11.,   3.]),
#  array([-3.30482058, -2.62382344, -1.94282631, -1.26182917, -0.58083204,
#          0.1001651 ,  0.78116223,  1.46215937,  2.1431565 ,  2.82415364,
#          3.50515078]),
#  <BarContainer object of 10 artists>)
