# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Hey so this is the markdown tab.
#
# $$ AMD_k = m_k \sqrt{G m_0 a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)$$
#
# Total AMD,
#
# $$ AMD = \sum_{k=1}^M AMD_k = \sum_k m_k \sqrt{G m_0 a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)$$
#
# The Normalised AMD,
#
# $$NAMD = \frac{\sum_k m_k \sqrt{G m_0 a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)}{\sum_k m_k \sqrt{G m_0 a_k}} $$
#
# $$\Rightarrow NAMD = \frac{\sum_k m_k \sqrt{a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)}{\sum_k m_k \sqrt{a_k}}$$

# %% [markdown]
# $$ \Delta a(t) = \Delta a_{now} - \Delta_0 \exp{(-t/\tau)}$$
#
# and
#
# $$ a(t) = a_{now} - \Delta a \exp{(-t/\tau_C)}$$

# %%
ax1 = np.random.normal(0,1,100000)
ax2 = np.random.normal(5,1,100000)
ax3 = np.sqrt(ax1**2 + ax2**2)
plt.hist(ax3)
# Out:
# (array([3.0000e+01, 6.3300e+02, 5.3160e+03, 1.9160e+04, 3.3664e+04,
#         2.8164e+04, 1.0921e+04, 1.9250e+03, 1.8000e+02, 7.0000e+00]),
#  array([0.87737303, 1.76727744, 2.65718186, 3.54708627, 4.43699069,
#         5.32689511, 6.21679952, 7.10670394, 7.99660835, 8.88651277,
#         9.77641718]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.normal(0,1,1000)
y = np.random.normal(1,1,1000)

z = x + y

plt.hist(z, bins=10)
# Out:
# (array([  6.,  22.,  66., 126., 213., 246., 187.,  87.,  40.,   7.]),
#  array([-3.42692226, -2.59082467, -1.75472708, -0.91862949, -0.08253189,
#          0.7535657 ,  1.58966329,  2.42576089,  3.26185848,  4.09795607,
#          4.93405366]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Alright, so things seems working.

# %%
plt.hist(x)
# Out:
# (array([  3.,   4.,  24.,  96., 213., 299., 210., 116.,  28.,   7.]),
#  array([-4.0083696 , -3.28586416, -2.56335872, -1.84085328, -1.11834783,
#         -0.39584239,  0.32666305,  1.04916849,  1.77167394,  2.49417938,
#          3.21668482]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# It is not on the GitHub. Idk what's going wrong with it

# %%
cc = np.random.exponential(1,100)
plt.hist(cc)
# Out:
# (array([25., 24., 20., 10.,  8.,  6.,  2.,  2.,  2.,  1.]),
#  array([0.02292325, 0.47549843, 0.92807361, 1.38064879, 1.83322397,
#         2.28579915, 2.73837433, 3.19094951, 3.64352469, 4.09609987,
#         4.54867506]),
#  <BarContainer object of 10 artists>)
