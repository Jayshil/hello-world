# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Hey so this is the markdown tab.
#
# $$ AMD_k = m_k \sqrt{G m_0 a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)$$
#
# Total AMD,
#
# $$ AMD = \sum_{k=1}^M AMD_k = \sum_k m_k \sqrt{G m_0 a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)$$
#
# The Normalised AMD,
#
# \begin{equation}
#     \begin{split}
#         NAMD &= \frac{\sum_k m_k \sqrt{G m_0 a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)}{\sum_k m_k \sqrt{G m_0 a_k}}\\
#         &= \frac{\sum_k m_k \sqrt{a_k} \left( 1 - \sqrt{1-e_k^2} \cdot \cos{i_k} \right)}{\sum_k m_k \sqrt{a_k}}
#     \end{split}
# \end{equation}

# %% [markdown]
# $$ \Delta a(t) = \Delta a_{now} - \Delta_0 \exp{(-t/\tau)}$$
#
# and
#
# $$ a(t) = a_{now} - \Delta a \exp{(-t/\tau_C)}$$

# %%
x = np.random.normal(0,1,1000)
y = np.random.normal(1,1,1000)

z = x + y

plt.hist(z, bins=10)
# Out:
# (array([ 12.,  29.,  94., 179., 209., 239., 148.,  71.,  16.,   3.]),
#  array([-3.35340384, -2.45178288, -1.55016193, -0.64854097,  0.25307998,
#          1.15470094,  2.05632189,  2.95794285,  3.8595638 ,  4.76118476,
#          5.66280571]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Alright, so things seems working.

# %%
plt.hist(x)
# Out:
# (array([  4.,  14.,  66., 166., 256., 269., 149.,  57.,  17.,   2.]),
#  array([-3.55125981, -2.83726094, -2.12326208, -1.40926321, -0.69526435,
#          0.01873451,  0.73273338,  1.44673224,  2.16073111,  2.87472997,
#          3.58872883]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# It is not on the GitHub. Idk what's going wrong with it

# %%
cc = np.random.exponential(1,100)
plt.hist(cc)
# Out:
# (array([28., 22., 17.,  9.,  4.,  5.,  8.,  4.,  2.,  1.]),
#  array([0.02153776, 0.36836798, 0.7151982 , 1.06202842, 1.40885864,
#         1.75568886, 2.10251909, 2.44934931, 2.79617953, 3.14300975,
#         3.48983997]),
#  <BarContainer object of 10 artists>)
