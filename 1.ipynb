# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Hey so this is the markdown tab.

# %%
x = np.random.normal(0,1,1000)
y = np.random.normal(1,1,1000)

z = x + y

plt.hist(z, bins=10)
# Out:
# (array([  8.,  34.,  98., 217., 215., 220., 137.,  48.,  17.,   6.]),
#  array([-3.18425159, -2.29695852, -1.40966545, -0.52237238,  0.36492068,
#          1.25221375,  2.13950682,  3.02679988,  3.91409295,  4.80138602,
#          5.68867909]),
#  <BarContainer object of 10 artists>)
