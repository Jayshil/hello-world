# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Alright, so I have created another notebook, but don't really know what to do.
#
# Uoo, ooo, I know, I can always check the \latex version here.
#
# But, what formula? Gaussian maybe?!
#
# $$p(y|\theta) = \frac{1}{\sqrt{2\pi}\sigma} e^{-\frac{x^2}{2\sigma^2}}$$

# %% [markdown]
# Well, it seems to be working. And I like it better than the anaconda version of the same thig!! But, now let's try some coding!!

# %%
x = np.random.normal(1,0.5,1000)
y = np.random.normal(2,0.5,1000)

def logsummation(a,b):
    z = np.log(x) + np.log(y)
    return z

# %%
bc = logsummation(x,y)
plt.hist(bc)
# Out:
# (array([  2.,   2.,   1.,   1.,   8.,   6.,  37., 178., 528., 220.]),
#  array([-6.44696056, -5.61114757, -4.77533458, -3.9395216 , -3.10370861,
#         -2.26789562, -1.43208263, -0.59626964,  0.23954335,  1.07535633,
#          1.91116932]),
#  <BarContainer object of 10 artists>)

# %%
zz = x + y
plt.hist(zz)
# Out:
# (array([  5.,  16.,  67., 159., 235., 243., 164.,  88.,  17.,   6.]),
#  array([0.71915502, 1.17636177, 1.63356853, 2.09077528, 2.54798203,
#         3.00518879, 3.46239554, 3.91960229, 4.37680905, 4.8340158 ,
#         5.29122255]),
#  <BarContainer object of 10 artists>)
